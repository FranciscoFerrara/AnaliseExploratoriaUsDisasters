# %% [markdown]
# # Análise Exploratória US-Disasters
#
# Utilizei os dados de um dataset obtido no Kaggle:
# https://www.kaggle.com/datasets/headsortails/us-natural-disaster-declarations
#
# Que usou como base:
# https://www.fema.gov

# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv("us_disaster_declarations.csv")
df2 = pd.read_csv("netflix daily top 10.csv")

# %% [markdown]
# #### Visualizando a base:

# %%
df.head()
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
# 1                 DR-2-TX                2    TX               DR
# 2                 DR-3-LA                3    LA               DR
# 3                 DR-4-MI                4    MI               DR
# 4                 DR-5-MT                5    MT               DR
#
#        declaration_date  fy_declared incident_type         declaration_title  \
# 0  1953-05-02T00:00:00Z         1953       Tornado                   Tornado
# 1  1953-05-15T00:00:00Z         1953       Tornado  Tornado & Heavy Rainfall
# 2  1953-05-29T00:00:00Z         1953         Flood                     Flood
# 3  1953-06-02T00:00:00Z         1953       Tornado                   Tornado
# 4  1953-06-06T00:00:00Z         1953         Flood                    Floods
#
#    ih_program_declared  ia_program_declared  ...     incident_end_date  \
# ...

# %%
df.tail()
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 64082              DR-4696-ME             4696    ME               DR
# 64083              DR-4696-ME             4696    ME               DR
# 64084              DR-4696-ME             4696    ME               DR
# 64085              DR-4696-ME             4696    ME               DR
# 64086              DR-4696-ME             4696    ME               DR
#
#            declaration_date  fy_declared incident_type  \
# 64082  2023-03-22T00:00:00Z         2023  Severe Storm
# 64083  2023-03-22T00:00:00Z         2023  Severe Storm
# 64084  2023-03-22T00:00:00Z         2023  Severe Storm
# 64085  2023-03-22T00:00:00Z         2023  Severe Storm
# 64086  2023-03-22T00:00:00Z         2023  Severe Storm
#
#                declaration_title  ih_program_declared  ia_program_declared  \
# 64082  Severe Storm And Flooding                    0                    0
# ...

# %% [markdown]
# #### Saber o tamanho da base:

# %%
df.shape
# Out:
# (64087, 23)

# %% [markdown]
# #### Visualizar a base que importei e outra forma de ver o tamanho dela:

# %%
display(df)
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# 64082              DR-4696-ME             4696    ME               DR
# 64083              DR-4696-ME             4696    ME               DR
# 64084              DR-4696-ME             4696    ME               DR
# 64085              DR-4696-ME             4696    ME               DR
# 64086              DR-4696-ME             4696    ME               DR
#
#            declaration_date  fy_declared incident_type  \
# 0      1953-05-02T00:00:00Z         1953       Tornado
# ...

# %% [markdown]
# #### Descobrindo o período da análise

# %%
inicio = df['fy_declared'].min()
print(inicio)
# Out:
# 1953

# %%
fim = df['fy_declared'].max()
print(fim)
# Out:
# 2023

# %% [markdown]
# #### Verificar valores nulos e tipo de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64087 entries, 0 to 64086
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     64087 non-null  object
#  1   disaster_number             64087 non-null  int64
#  2   state                       64087 non-null  object
#  3   declaration_type            64087 non-null  object
#  4   declaration_date            64087 non-null  object
#  5   fy_declared                 64087 non-null  int64
#  6   incident_type               64087 non-null  object
#  7   declaration_title           64087 non-null  object
#  8   ih_program_declared         64087 non-null  int64
#  9   ia_program_declared         64087 non-null  int64
#  10  pa_program_declared         64087 non-null  int64
#  11  hm_program_declared         64087 non-null  int64
#  12  incident_begin_date         64087 non-null  object
# ...

# %% [markdown]
# #### Verificando o tipo dos dados

# %%
df.dtypes
# Out:
# fema_declaration_string       object
# disaster_number                int64
# state                         object
# declaration_type              object
# declaration_date              object
# fy_declared                    int64
# incident_type                 object
# declaration_title             object
# ih_program_declared            int64
# ia_program_declared            int64
# pa_program_declared            int64
# hm_program_declared            int64
# incident_begin_date           object
# incident_end_date             object
# disaster_closeout_date        object
# fips                           int64
# place_code                     int64
# designated_area               object
# declaration_request_number     int64
# last_ia_filing_date           object
# last_refresh                  object
# hash                          object
# id                            object
# dtype: object

# %% [markdown]
# #### Verificando a existência de valores nulos

# %%
df.isnull().sum()
# Out:
# fema_declaration_string           0
# disaster_number                   0
# state                             0
# declaration_type                  0
# declaration_date                  0
# fy_declared                       0
# incident_type                     0
# declaration_title                 0
# ih_program_declared               0
# ia_program_declared               0
# pa_program_declared               0
# hm_program_declared               0
# incident_begin_date               0
# incident_end_date              8410
# disaster_closeout_date        14449
# fips                              0
# place_code                        0
# designated_area                   0
# declaration_request_number        0
# last_ia_filing_date           46338
# last_refresh                      0
# hash                              0
# id                                0
# dtype: int64

# %% [markdown]
# #### Entendendo melhor os valores nulos

# %%
df['last_ia_filing_date'].value_counts()
# Out:
# 2023-06-01T00:00:00Z    4156
# 2006-04-10T00:00:00Z     464
# 1998-10-24T00:00:00Z     257
# 2006-05-30T00:00:00Z     254
# 2021-05-20T00:00:00Z     254
#                         ...
# 2003-02-18T00:00:00Z       1
# 2021-01-04T00:00:00Z       1
# 2000-06-06T00:00:00Z       1
# 2001-11-20T00:00:00Z       1
# 1999-09-17T00:00:00Z       1
# Name: last_ia_filing_date, Length: 485, dtype: int64

# %% [markdown]
# #### Analisando as informações estatísticas

# %%
df.describe()
# Out:
#        disaster_number   fy_declared  ih_program_declared  \
# count     64087.000000  64087.000000         64087.000000
# mean       2576.940097   2004.338540             0.168037
# std        1405.466011     14.784951             0.373902
# min           1.000000   1953.000000             0.000000
# 25%        1316.000000   1997.000000             0.000000
# 50%        3057.000000   2007.000000             0.000000
# 75%        3545.000000   2018.000000             0.000000
# max        5457.000000   2023.000000             1.000000
#
#        ia_program_declared  pa_program_declared  hm_program_declared  \
# count         64087.000000         64087.000000         64087.000000
# mean              0.268182             0.932030             0.431445
# std               0.443017             0.251697             0.495282
# min               0.000000             0.000000             0.000000
# 25%               0.000000             1.000000             0.000000
# ...

# %% [markdown]
# #### Entendendo melhor essas informações

# %%
df.plot(kind='box',figsize=(20,6),subplots=True);

# %% [markdown]
# ##### O que seriam esses outliers?

# %%
df[df['fy_declared'] >= 2010]
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 37196              FM-2840-AZ             2840    AZ               FM
# 37197              FM-2841-CA             2841    CA               FM
# 37198              EM-3306-PR             3306    PR               EM
# 37199              EM-3306-PR             3306    PR               EM
# 37200              EM-3306-PR             3306    PR               EM
# ...                       ...              ...   ...              ...
# 64082              DR-4696-ME             4696    ME               DR
# 64083              DR-4696-ME             4696    ME               DR
# 64084              DR-4696-ME             4696    ME               DR
# 64085              DR-4696-ME             4696    ME               DR
# 64086              DR-4696-ME             4696    ME               DR
#
#            declaration_date  fy_declared incident_type  \
# 37196  2009-10-03T00:00:00Z         2010          Fire
# ...

# %%
df_excel = df[df['fy_declared'] >= 2010]
df_excel.to_excel('Verificar.xlsx')

# %% [markdown]
# #### Analisando esses dados, posso agora verificar qual foi o maior tipo de desastre num período de 10 anos antes e após 2010

# %%
df.title.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 df.title.value_counts()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'title'

# %%
df.Type.value_counts().plot(kind='bar');

# %%
df['Viewership Score'].hist();

# %%
df[df['Viewership Score'] == df['Viewership Score'].max()]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank      Title     Type  \
# 6998  2022-03-01     9                 -              -  Cocomelon  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 6998               NaN          Jun 1, 2020             428              1474
